# %% [markdown]
# # <span style="color:darkblue"> Lecture 1e - Dictionaries </span>
#
# <font size = "5">
#
# In the previous lecture we covered lists to store objects.
#
# - An alternative are dictionaries
# - Lists retrieve information based on a position {0,1,2,3},
# whereas dictionaries use "keys" (named values)
# - Both allow for nesting
# - They can be combined

# %% [markdown]
# <font size = "5">
#
# Examples of Dictionary Formatting
#
# - Each "key" is associated with a "value"
# - Different keys can store different data types

# %%
# Define dictionary
dictionary_student = \
{
    "first_name": "John",
    "last_name" : "Smith",
    "location"  : "Atlanta",
    "university": "Emory",
    "age": 30
}

# Retrieve specific information
# key: "first_name"
# value: "John"

print( dictionary_student["first_name"])
# Out:
# John

# %% [markdown]
# <font size = "5">
# Nested dictionaries

# %%
dictionary_student_wgrades =\
{
    "first_name": "John",
    "last_name" : "Smith",
    "location"  : "Atlanta",
    "university": "Emory",
    "grades":{
        "computing":"A",
        "reasoning":"B",
        "applied":"A-"
    }
}

# Retrieve information within the list

print( dictionary_student_wgrades["grades"]["computing"])
# Out:
# A

# %% [markdown]
# <font size = "5">
# Nested dictionaries + Lists

# %%
dictionary_liststudents = \
[{
    "first_name": "Ned",
    "last_name" : "Stark",
    "location"  : "Atlanta",
    "university": "Emory",
    
 },
 {
    "first_name": "Cersei",
    "last_name" : "Lannister",
    "location"  : "Decatur",
    "university": "Georgia Tech",
 }
]

print( dictionary_liststudents[0]["first_name"])
# Out:
# Ned

# %% [markdown]
# <font size = "5">
#
# Try it yourself!
#
# - Create your own dictionary.

# %%
# Write your own code

dictionary_listanimals = \
[{
    "name": "Ned",
    "gender" : "male",
    "location"  : "Atlanta",
    "type": "cat",
    
 },
 {
    "name": "Cersei",
    "gender" : "female",
    "location"  : "Decatur",
    "type": "dog",
 }
]

print( dictionary_listanimals[0]["name"])
# Out:
# Ned
